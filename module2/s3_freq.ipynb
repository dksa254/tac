# %% [markdown]
# # Analyse frequency distribution of words

# %% [markdown]
# ## Installation des dépendences

# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sarah\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Création d'une liste de stopwords

# %%
from nltk.corpus import stopwords

sw = stopwords.words("french")
sw += ["les", "plus", "cette", "fait", "faire", "être", "deux", "comme", "dont", "tout", 
       "ils", "bien", "sans", "peut", "tous", "après", "ainsi", "donc", "cet", "sous",
       "celle", "entre", "encore", "toutes", "pendant", "moins", "dire", "cela", "non",
       "faut", "trois", "aussi", "dit", "avoir", "doit", "contre", "depuis", "autres",
       "van", "het", "autre", "jusqu"]
sw = set(sw)
print(f"{len(sw)} stopwords used: {sorted(sw)}")
# Out:
# 197 stopwords used: ['ai', 'aie', 'aient', 'aies', 'ainsi', 'ait', 'après', 'as', 'au', 'aura', 'aurai', 'auraient', 'aurais', 'aurait', 'auras', 'aurez', 'auriez', 'aurions', 'aurons', 'auront', 'aussi', 'autre', 'autres', 'aux', 'avaient', 'avais', 'avait', 'avec', 'avez', 'aviez', 'avions', 'avoir', 'avons', 'ayant', 'ayante', 'ayantes', 'ayants', 'ayez', 'ayons', 'bien', 'c', 'ce', 'cela', 'celle', 'ces', 'cet', 'cette', 'comme', 'contre', 'd', 'dans', 'de', 'depuis', 'des', 'deux', 'dire', 'dit', 'doit', 'donc', 'dont', 'du', 'elle', 'en', 'encore', 'entre', 'es', 'est', 'et', 'eu', 'eue', 'eues', 'eurent', 'eus', 'eusse', 'eussent', 'eusses', 'eussiez', 'eussions', 'eut', 'eux', 'eûmes', 'eût', 'eûtes', 'faire', 'fait', 'faut', 'furent', 'fus', 'fusse', 'fussent', 'fusses', 'fussiez', 'fussions', 'fut', 'fûmes', 'fût', 'fûtes', 'het', 'il', 'ils', 'j', 'je', 'jusqu', 'l', 'la', 'le', 'les', 'leur', 'lui', 'm', 'ma', 'mais', 'me', 'mes', 'moi', 'moins', 'mon', 'même', 'n', 'ne', 'non', 'nos', 'notre', 'nous', 'on', 'ont', 'ou', 'par', 'pas', 'pendant', 'peut', 'plus', 'pour', 'qu', 'que', 'qui', 's', 'sa', 'sans', 'se', 'sera', 'serai', 'seraient', 'serais', 'serait', 'seras', 'serez', 'seriez', 'serions', 'serons', 'seront', 'ses', 'soient', 'sois', 'soit', 'sommes', 'son', 'sont', 'sous', 'soyez', 'soyons', 'suis', 'sur', 't', 'ta', 'te', 'tes', 'toi', 'ton', 'tous', 'tout', 'toutes', 'trois', 'tu', 'un', 'une', 'van', 'vos', 'votre', 'vous', 'y', 'à', 'étaient', 'étais', 'était', 'étant', 'étante', 'étantes', 'étants', 'étiez', 'étions', 'été', 'étée', 'étées', 'étés', 'êtes', 'être']

# %% [markdown]
# ## Visualiser les termes les plus fréquents

# %%
path = "../data/all.txt"
limit = 10**8

with open(path, encoding='latin-1') as f:
    text = f.read()[:limit]
    words = nltk.wordpunct_tokenize(text)
    print(f"{len(words)} words found")
    kept = [w.lower() for w in words if len(w) > 2 and w.isalpha() and w.lower() not in sw]
    voc = set(kept)
    print(f"{len(kept)} words kept ({len(voc)} different word forms)")
    fdist = nltk.FreqDist(kept)
    print(fdist.most_common(50))
    fdist.plot(50, cumulative=True)
    print(fdist.hapaxes())
    long_words = [w for w in voc if len(w) > 15]
    print(sorted(long_words))
# Out:
# 27890820 words found
# 6604846 words kept (134671 different word forms)
# [('rue', 63154), ('prã', 56493), ('conseil', 44628), ('ville', 43557), ('francs', 43452), ('collã', 38130), ('section', 28698), ('ãªtre', 27108), ('bruxelles', 27089), ('art', 26224), ('bourgmestre', 24845), ('travaux', 22872), ('administration', 21208), ('rapport', 20853), ('intã', 18805), ('annã', 16812), ('crã', 16753), ('messieurs', 16415), ('demande', 15434), ('hospices', 15295), ('question', 15138), ('frais', 14997), ('aprã', 14874), ('mãªme', 14732), ('echevin', 14700), ('service', 14680), ('tre', 14586), ('ance', 14581), ('somme', 13864), ('communal', 13679), ('prix', 13575), ('penses', 13532), ('tres', 12847), ('avis', 12797), ('projet', 12774), ('place', 12686), ('lieu', 12627), ('finances', 12626), ('partie', 12545), ('propriã', 12515), ('pense', 12414), ('budget', 12400), ('publique', 12231), ('tait', 12231), ('proposition', 12211), ('compte', 12074), ('police', 11986), ('exã', 11217), ('droit', 11078), ('nombre', 10993)]
# eet', 'desoumettrequelques', 'despropositionsavaient', 'desprotestations', 'desterrainsappartenant', 'detteflottantecrã', 'deuxicmealignement', 'devantterritoire', 'deviendrionsnous', 'devjnsetdelioissonsdistiuã', 'dictionnairement', 'diflerentessentiellement', 'directeurprofesseur', 'disciplinairement', 'disgracieusement', 'distributiondediverssecoursparlescomitã', 'diversespensions', 'documentsparlementaires', 'doivenlaboulirprã', 'doiventãªtreconsultã', 'donnepasseulement', 'dontleurcomptabilitã', 'dosfinancespropose', 'dramatiqueflamande', 'dramatiqueflamandepar', 'dramatiqueflamandun', 'dramatiquesflamandeset', 'dramatiquesflamandesse', 'droitappartieudra', 'droitdeplaceaumarchã', 'droitdesindigenlssurlesbalsetdivertissementspublics', 'droitdesindigentssurles', 'droitdesindigentssurlesbalsctdivcrtisscmcntspublics', 'dusubsidedelaprovin', 'eartraordinaires', 'echeveinlemaieur', 'echevindelecosse', 'echevindolecosse', 'echevinfontainas', 'eelievindekeyser', 'egoulsauxabordsdcssquares', 'eiwifcrityaafrfã', 'ejcommissariatdepol', 'elleauloriserait', 'ellefiniraitpuavoir', 'ellementpourquoi', 'ellesentimentdudevoir', 'embarrasseraient', 'embellissementdu', 'emplacementproposã', 'empãªchecourbure', 'encorefigurerdes', 'enfantsrachitiques', 'enfiniraitjamais', 'enfl